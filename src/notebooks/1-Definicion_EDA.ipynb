# %% [markdown]
# ![imagen](./img/pokemon_print.jpg)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# # Pokemon respondiendo a las grandes preguntas

# %% [markdown]
# Durante este análisis exhaustivo (EDA), exploraremos todas las estadísticas, posibilidades y, sobre todo, datos para dar forma a las hipótesis  más buscadas por los fans de la saga.
# ¡Por fin se acabarán las discusiones!

# %% [markdown]
# ## Hipotesis principal
# ¿Es Pikachu la mejor elección para ser el favorito de Ash o existen otros mejores?

# %% [markdown]
# ## Hipótesis secundarias
# 1. ¿Es Eternatus el Pokémon más fuerte?
# 2. ¿Es Charmander la mejor elección inicial, o lo son Squirtle o Bulbasaur?
# 3. ¿Cuál es el grupo de Pokémon más fuertes?
# 4. ¿Tiene alguna posibilidad el Team Rocket de ganar alguna batalla, teniendo en cuenta sus Pokémon?

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import pandas as pd
df_pokestats = pd.read_csv('./data/pokemon.csv')

# %%
df_pokestats.head(25)
# Out:
#      #                       Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 0    1                  Bulbasaur   Grass  Poison    318  45      49       49
# 1    2                    Ivysaur   Grass  Poison    405  60      62       63
# 2    3                   Venusaur   Grass  Poison    525  80      82       83
# 3    3      VenusaurMega Venusaur   Grass  Poison    625  80     100      123
# 4    4                 Charmander    Fire     NaN    309  39      52       43
# 5    5                 Charmeleon    Fire     NaN    405  58      64       58
# 6    6                  Charizard    Fire  Flying    534  78      84       78
# 7    6  CharizardMega Charizard X    Fire  Dragon    634  78     130      111
# 8    6  CharizardMega Charizard Y    Fire  Flying    634  78     104       78
# 9    7                   Squirtle   Water     NaN    314  44      48       65
# 10   8                  Wartortle   Water     NaN    405  59      63       80
# ...

# %% [markdown]
# webscraping. Consulta la lista completa de Pokémon del año en [WikiDex](https://www.wikidex.net/wiki/Pok%C3%A9mon_del_a%C3%B1o).
